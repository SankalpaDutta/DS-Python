# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# # Creating Conditional columns

# %%
nba=pd.read_csv("nba.csv")
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba["Is Weight"]=np.where(nba["Weight"]>=200,1,0)
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary  Is Weight
# 0              Texas  7730337.0          0
# 1          Marquette  6796117.0          1
# 2  Boston University        NaN          1
# 3      Georgia State  1148640.0          0
# 4                NaN  5000000.0          1

# %%
#Ceating Columns based on multiple conditions
#conditions = [
 #   (nba['Weight'] >= '200') & (nba['Position'] == 'PG'),
  #  (nba['Weight'] >= '200') & (nba['Position'] == 'SG'),
  #  (nba['Weight'] >= '230')]
#choices = ['PG more than 200', 'SG more than 200', 'More than 250']
#nba['Multiple condition column'] = np.select(conditions, choices, default='black')
#print(nba)

# %%
df=pd.read_csv("train.csv")

# %%
df.head(3)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
#
# [3 rows x 81 columns]

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# PoolQC           1453
# MiscFeature      1406
# Alley            1369
# Fence            1179
# FireplaceQu       690
# LotFrontage       259
# GarageCond         81
# GarageType         81
# GarageYrBlt        81
# GarageFinish       81
# GarageQual         81
# BsmtExposure       38
# BsmtFinType2       38
# BsmtFinType1       37
# BsmtCond           37
# BsmtQual           37
# MasVnrArea          8
# MasVnrType          8
# Electrical          1
# Utilities           0
# YearRemodAdd        0
# MSSubClass          0
# Foundation          0
# ExterCond           0
# ExterQual           0
# Exterior2nd         0
# Exterior1st         0
# RoofMatl            0
# RoofStyle           0
# YearBuilt           0
#                  ...
# GarageArea          0
# PavedDrive          0
# WoodDeckSF          0
# OpenPorchSF         0
# 3SsnPorch           0
# BsmtUnfSF           0
# ScreenPorch         0
# PoolArea            0
# MiscVal             0
# MoSold              0
# ...

# %%
number_of_records=df.index.value_counts().sum()
null_values=df.isna().sum()

# %%
percent=null_values/number_of_records

# %%
percent.sort_values(ascending=False).head(20)
#nba.sort_values(["Team", "Name"], ascending = [True, False], inplace = True)
#nba.sort_index(ascending = False, inplace = True)
# Out:
# PoolQC          0.995205
# MiscFeature     0.963014
# Alley           0.937671
# Fence           0.807534
# FireplaceQu     0.472603
# LotFrontage     0.177397
# GarageCond      0.055479
# GarageType      0.055479
# GarageYrBlt     0.055479
# GarageFinish    0.055479
# GarageQual      0.055479
# BsmtExposure    0.026027
# BsmtFinType2    0.026027
# BsmtFinType1    0.025342
# BsmtCond        0.025342
# BsmtQual        0.025342
# MasVnrArea      0.005479
# MasVnrType      0.005479
# Electrical      0.000685
# Utilities       0.000000
# dtype: float64

# %%
#nba.dropna(how = "all", inplace = True)
#to drop all rows with NA values

# %%
#df.dropna(subset = ["FireplaceQu", "Fence","Alley","MiscFeature","PoolQC"])
#to remove all rows for meantioned columns being null

# %%
#dropping columns with high null values
df=df.drop(["FireplaceQu", "Fence","Alley","MiscFeature","PoolQC"], axis=1)
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig    ...     EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 0    AllPub    Inside    ...                 0         0           0        0
# 1    AllPub       FR2    ...                 0         0           0        0
# 2    AllPub    Inside    ...                 0         0           0        0
# 3    AllPub    Corner    ...               272         0           0        0
# 4    AllPub       FR2    ...                 0         0           0        0
#
# ...

# %%
#nba["Salary"].fillna(0, inplace = True)
#fill mentioned columns with value of choice

# %%
df=df.dropna(how = "all", inplace = True)

df.isna().sum().sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-122-60f4297ad2b5> in <module>()
#       1 df=df.dropna(how = "all", inplace = True)
#       2
# ----> 3 df.isna().sum().sort_values(ascending=False)
#
# AttributeError: 'NoneType' object has no attribute 'isna'

# %%
df["YrSold"] = df["YrSold"].astype("int") # change the data type to required format

# %%
#nba["Age"].astype("float")
#nba["Team"] = nba["Team"].astype("category")
#astype("bool")

# %% [markdown]
# # Filter with More than One Condition (AND)/(OR)

# %%
#mask1 = df["Gender"] == "Male"
#mask2 = df["Team"] == "Marketing"

#df[mask1 & mask2]

# %%
#mask1 = df["Senior Management"]
#mask2 = df["Start Date"] < "1990-01-01"

#df[mask1 | mask2]

# %% [markdown]
# ### Filter out the non null rows

# %%
#condition = df["Gender"].notnull()
#select clumn with

# %% [markdown]
# ### Get values btw an interval

# %%
#df[df["Salary"].between(60000, 70000)]

# %% [markdown]
# ### Remove duplicate values

# %%
#mask = ~df["First Name"].duplicated(keep = False)
#df[mask]
#DataFrame.duplicated(subset=None, keep='first')[source]
#Return boolean Series denoting duplicate rows, optionally only considering certain columns

# %%
#df.drop_duplicates(subset = ["First Name"], keep = False)

# %%
#DataFrame.drop_duplicates(subset=None, keep='first', inplace=False)[source]
#Return DataFrame with duplicate rows removed, optionally only considering certain columns

# %%
#df.loc["LotFrontage" : "LotConfig"] # get rows from mentioned values till mentioned values

# %%
df.iloc[:4]
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
#
#   Utilities LotConfig    ...     EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 0    AllPub    Inside    ...                 0         0           0        0
# 1    AllPub       FR2    ...                 0         0           0        0
# 2    AllPub    Inside    ...                 0         0           0        0
# 3    AllPub    Corner    ...               272         0           0        0
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0       0      2    2008        WD         Normal     208500
# 1       0      5    2007        WD         Normal     181500
# ...

# %%
#sectors = df.groupby("LotShape")
#sectors.head()

# %%
df.where(pd.notna(df), df.mean(), axis='columns')
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL    65.000000     8450   Pave   NaN      Reg
# 1        2          20       RL    80.000000     9600   Pave   NaN      Reg
# 2        3          60       RL    68.000000    11250   Pave   NaN      IR1
# 3        4          70       RL    60.000000     9550   Pave   NaN      IR1
# 4        5          60       RL    84.000000    14260   Pave   NaN      IR1
# 5        6          50       RL    85.000000    14115   Pave   NaN      IR1
# 6        7          20       RL    75.000000    10084   Pave   NaN      Reg
# 7        8          60       RL    70.049958    10382   Pave   NaN      IR1
# 8        9          50       RM    51.000000     6120   Pave   NaN      Reg
# 9       10         190       RL    50.000000     7420   Pave   NaN      Reg
# 10      11          20       RL    70.000000    11200   Pave   NaN      Reg
# ...

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...
